# %%
import pandas as pd

# %%
DATADIR = 'C:\\Users\\max\\JupiterProjects\\homework_42\\names\\'

# %%
names_1950 = pd.read_csv('{}yob{}.txt'.format(DATADIR, '1950'), names=['Names', 'Gender', 'Count']).groupby('Names').sum()

# %%
names_1950_top10R = names_1950['R':'S'].sort_values('Count', ascending=False).head(10)

# %%
names_1950_top10R.plot.pie(y='Count')
